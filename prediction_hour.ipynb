# %%
import numpy as np
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense,SimpleRNN,LSTM,GRU,Dropout,merge
from keras.layers import LSTM
from keras.callbacks import TensorBoard
import time
import os
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
NAME1="LSTM-hour-mae-adam{}".format(int(time.time()))
tensorboard=TensorBoard(log_dir='Miniproj2/{}'.format(NAME1))

# %%
data=np.load('polution_dataSet.npy')

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in, n_out, dropnan=True):
    n_vars=data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        for j in range(n_vars):
            names += [('var%d(t-%d)' % (j+1, i))]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            for j in range(n_vars):
                names += [('var%d(t)' % (j+1))]
        else:
            for j in range(n_vars):
                names += [('var%d(t+%d)' % (j+1, i))]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
n_hours=24
n_features=8
reframed = series_to_supervised(data, n_hours,1)

# %%
values = reframed.values
n_train_hours = 7000
n_validation_hours=1000
n_test_hours=2000
train = values[:n_train_hours, :]
validation=values[n_train_hours :n_train_hours+n_validation_hours,:]
test = values[n_train_hours+n_validation_hours:n_train_hours+n_validation_hours+n_test_hours, :]
# split into input and outputs
n_obs = n_hours * n_features
train_X, train_y = train[:, :n_obs], train[:, -n_features]
validation_X,validation_y=validation[:, :n_obs], validation[:, -n_features]
test_X, test_y = test[:, :n_obs], test[:, -n_features]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
validation_X=validation_X.reshape((validation_X.shape[0], n_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))
print(train_X.shape, train_y.shape,validation_X.shape, validation_y.shape, test_X.shape, test_y.shape)
# Out:
# (7000, 24, 8) (7000,) (1000, 24, 8) (1000,) (2000, 24, 8) (2000,)

# %%
# design network
model = Sequential()
#model.add(SimpleRNN(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(GRU(50, input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dropout(0.1))
model.add(Dense(1))
#model.add(Dropout(0.1))
model.compile(loss='mae', optimizer='adam')
# fit network
time1 = time.clock()
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(validation_X, validation_y), verbose=2, shuffle=False,callbacks=[tensorboard])
time2 = time.clock()
print("It took %d seconds to train"%(time2-time1))
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='validation')
pyplot.legend()
pyplot.show()
# Out:
# Train on 7000 samples, validate on 1000 samples
# Epoch 1/50
#  - 4s - loss: 0.0555 - val_loss: 0.0393
# Epoch 2/50
#  - 2s - loss: 0.0426 - val_loss: 0.0328
# Epoch 3/50
#  - 2s - loss: 0.0365 - val_loss: 0.0292
# Epoch 4/50
#  - 2s - loss: 0.0333 - val_loss: 0.0280
# Epoch 5/50
#  - 3s - loss: 0.0314 - val_loss: 0.0265
# Epoch 6/50
#  - 3s - loss: 0.0305 - val_loss: 0.0235
# Epoch 7/50
#  - 5s - loss: 0.0296 - val_loss: 0.0241
# Epoch 8/50
#  - 3s - loss: 0.0284 - val_loss: 0.0237
# Epoch 9/50
#  - 3s - loss: 0.0287 - val_loss: 0.0237
# Epoch 10/50
#  - 3s - loss: 0.0283 - val_loss: 0.0213
# Epoch 11/50
#  - 2s - loss: 0.0277 - val_loss: 0.0207
# Epoch 12/50
#  - 3s - loss: 0.0265 - val_loss: 0.0214
# Epoch 13/50
#  - 2s - loss: 0.0260 - val_loss: 0.0192
# Epoch 14/50
#  - 2s - loss: 0.0257 - val_loss: 0.0205
# Epoch 15/50
#  - 2s - loss: 0.0260 - val_loss: 0.0190
# Epoch 16/50
#  - 2s - loss: 0.0260 - val_loss: 0.0193
# Epoch 17/50
#  - 2s - loss: 0.0253 - val_loss: 0.0187
# Epoch 18/50
#  - 2s - loss: 0.0239 - val_loss: 0.0185
# Epoch 19/50
#  - 2s - loss: 0.0245 - val_loss: 0.0196
# Epoch 20/50
#  - 2s - loss: 0.0246 - val_loss: 0.0172
# Epoch 21/50
#  - 4s - loss: 0.0249 - val_loss: 0.0183
# Epoch 22/50
#  - 2s - loss: 0.0243 - val_loss: 0.0182
# Epoch 23/50
#  - 2s - loss: 0.0243 - val_loss: 0.0176
# Epoch 24/50
#  - 2s - loss: 0.0240 - val_loss: 0.0182
# Epoch 25/50
#  - 2s - loss: 0.0239 - val_loss: 0.0173
# Epoch 26/50
#  - 2s - loss: 0.0237 - val_loss: 0.0173
# Epoch 27/50
#  - 3s - loss: 0.0241 - val_loss: 0.0175
# Epoch 28/50
#  - 2s - loss: 0.0235 - val_loss: 0.0166
# Epoch 29/50
#  - 2s - loss: 0.0245 - val_loss: 0.0173
# Epoch 30/50
#  - 2s - loss: 0.0231 - val_loss: 0.0177
# Epoch 31/50
#  - 2s - loss: 0.0239 - val_loss: 0.0182
# Epoch 32/50
#  - 2s - loss: 0.0239 - val_loss: 0.0171
# Epoch 33/50
#  - 2s - loss: 0.0235 - val_loss: 0.0177
# Epoch 34/50
#  - 2s - loss: 0.0234 - val_loss: 0.0177
# Epoch 35/50
#  - 2s - loss: 0.0231 - val_loss: 0.0170
# Epoch 36/50
#  - 2s - loss: 0.0234 - val_loss: 0.0176
# Epoch 37/50
#  - 2s - loss: 0.0237 - val_loss: 0.0174
# Epoch 38/50
#  - 2s - loss: 0.0237 - val_loss: 0.0176
# Epoch 39/50
#  - 2s - loss: 0.0228 - val_loss: 0.0170
# Epoch 40/50
#  - 2s - loss: 0.0236 - val_loss: 0.0170
# Epoch 41/50
#  - 2s - loss: 0.0235 - val_loss: 0.0179
# Epoch 42/50
#  - 2s - loss: 0.0233 - val_loss: 0.0166
# Epoch 43/50
#  - 2s - loss: 0.0231 - val_loss: 0.0180
# Epoch 44/50
#  - 2s - loss: 0.0222 - val_loss: 0.0182
# Epoch 45/50
#  - 2s - loss: 0.0233 - val_loss: 0.0176
# Epoch 46/50
#  - 2s - loss: 0.0229 - val_loss: 0.0174
# Epoch 47/50
#  - 2s - loss: 0.0227 - val_loss: 0.0167
# Epoch 48/50
#  - 2s - loss: 0.0236 - val_loss: 0.0176
# Epoch 49/50
#  - 2s - loss: 0.0233 - val_loss: 0.0170
# Epoch 50/50
#  - 2s - loss: 0.0233 - val_loss: 0.0160
# It took 132 seconds to train

# %%
test_predict = model.predict(test_X)
rmse = sqrt(mean_squared_error(test_y, test_predict))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.028

# %%
train_predict=model.predict(train_X)
pyplot.plot(train_y,'g', label='real train values')
pyplot.plot(train_predict, 'm', alpha=0.6, label='model prediction for train')
pyplot.legend()
pyplot.show()

# %%
pyplot.plot(test_y,'g', label='real test values')
pyplot.plot(test_predict, 'm', alpha=0.6, label='model prediction for test')
pyplot.legend()
pyplot.show()
